# %%
import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
data = Dataset('OMI-Aura_L3-OMNO2d_2020m0301_v003-2020m0611t080447.he5.nc4', mode='r')

# %%
print(data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.InputPointer: OMI-Aura_L2-OMNO2_2020m0229t2229-o83118_v003-2020m0611t114324.he5,OMI-Aura_L2-OMNO2_2020m0301t0008-o83119_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t0147-o83120_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t0326-o83121_v003-2020m0611t114310.he5,OMI-Aura_L2-OMNO2_2020m0301t0505-o83122_v003-2020m0611t114320.he5,OMI-Aura_L2-OMNO2_2020m0301t0644-o83123_v003-2020m0611t114315.he5,OMI-Aura_L2-OMNO2_2020m0301t0822-o83124_v003-2020m0611t114316.he5,OMI-Aura_L2-OMNO2_2020m0301t1001-o83125_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t1140-o83126_v003-2020m0611t114317.he5,OMI-Aura_L2-OMNO2_2020m0301t1319-o83127_v003-2020m0611t114310.he5,OMI-Aura_L2-OMNO2_2020m0301t1458-o83128_v003-2020m0611t114306.he5,OMI-Aura_L2-OMNO2_2020m0301t1637-o83129_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t1816-o83130_v003-2020m0611t114309.he5,OMI-Aura_L2-OMNO2_2020m0301t1955-o83131_v003-2020m0611t114309.he5,OMI-Aura_L2-OMNO2_2020m0301t2134-o83132_v003-2020m0611t114313.he5,OMI-Aura_L2-OMNO2_2020m0301t2312-o83133_v003-2020m0611t114308.he5
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.InstrumentName: OMI
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.ProcessLevel: 3d
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.Period: Daily
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleYear: 2020
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleMonth: 3
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleDay: 1
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleDayOfYear: 61
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.StartUTC: 2020.0
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.EndUTC: 2020-03-02T00:00:00.000000Z
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.TAI93At0zOfGranule: 857088010.0
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.OrbitCount: 16
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.StartOrbit: 17582
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.EndOrbit: 17597
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.OrbitNumber: [83118 83119 83120 83121 83122 83123 83124 83125 83126 83127 83128 83129
#  83130 83131 83132 83133]
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.Resolution:  0.250 degrees
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.PGE: OMNO2d
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.PGEVersion: \"1.0.5.03\"
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.fullnamepath: /HDFEOS/ADDITIONAL/FILE_ATTRIBUTES
#     HDFEOS_GRIDS_ColumnAmountNO2.GCTPProjectionCode: 0
#     HDFEOS_GRIDS_ColumnAmountNO2.Projection: Geographic
#     HDFEOS_GRIDS_ColumnAmountNO2.GridOrigin: Center
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpacing: (0.25, 0.25)
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpacingUnit: deg
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpan: (-180,180,-90,90)
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpanUnit: deg
#     HDFEOS_GRIDS_ColumnAmountNO2.NumberOfLongitudesInGrid: 1440
#     HDFEOS_GRIDS_ColumnAmountNO2.NumberOfLatitudesInGrid: 720
#     HDFEOS_GRIDS_ColumnAmountNO2.fullnamepath: /HDFEOS/GRIDS/ColumnAmountNO2
#     HDFEOS_INFORMATION.HDFEOSVersion: HDFEOS_5.1.12
#     HDFEOS_INFORMATION.fullnamepath: /HDFEOS INFORMATION
#     history: 2021-07-21 06:11:08 GMT Hyrax-1.16.3 https://acdisc.gesdisc.eosdis.nasa.gov/opendap/HDF-EOS5/Aura_OMI_Level3/OMNO2d.003/2020/OMI-Aura_L3-OMNO2d_2020m0301_v003-2020m0611t080447.he5.nc4?ColumnAmountNO2TropCloudScreened[521:524][423:434],lat[521:524],lon[423:434]
#     dimensions(sizes): lat(4), lon(12)
#     variables(dimensions): float32 ColumnAmountNO2TropCloudScreened(lat, lon), float32 lon(lon), float32 lat(lat)
#     groups:

# %%
lons = data.variables['lon'][:]
lats = data.variables['lat'][:]
NO2 = data.variables['ColumnAmountNO2TropCloudScreened'][:,:]

# %%
# Set the figure size, projection, and extent
fig = plt.figure(figsize=(8,4))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines(resolution="110m",linewidth=1)
ax.gridlines(linestyle='--',color='black')

# Set contour levels, then draw the plot and a colorbar
clevs = np.arange(230,311,5)
plt.contourf(lons, lats, NO2, clevs, transform=ccrs.PlateCarree(),cmap=plt.cm.jet)
plt.title('NO2_concentrations, March 2020', size=14)
cb = plt.colorbar(ax=ax, orientation="vertical", pad=0.02, aspect=16, shrink=0.8)
cb.set_label('K',size=12,rotation=0,labelpad=15)
cb.ax.tick_params(labelsize=10)

# %%
fig.savefig('NO2_concentrations.png', format='png', dpi=360)

# %%
print(data.ncattrs)
# Out:
# <built-in method ncattrs of netCDF4._netCDF4.Dataset object at 0x0000024E75C8FE40>

# %%
print(data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.InputPointer: OMI-Aura_L2-OMNO2_2020m0229t2229-o83118_v003-2020m0611t114324.he5,OMI-Aura_L2-OMNO2_2020m0301t0008-o83119_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t0147-o83120_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t0326-o83121_v003-2020m0611t114310.he5,OMI-Aura_L2-OMNO2_2020m0301t0505-o83122_v003-2020m0611t114320.he5,OMI-Aura_L2-OMNO2_2020m0301t0644-o83123_v003-2020m0611t114315.he5,OMI-Aura_L2-OMNO2_2020m0301t0822-o83124_v003-2020m0611t114316.he5,OMI-Aura_L2-OMNO2_2020m0301t1001-o83125_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t1140-o83126_v003-2020m0611t114317.he5,OMI-Aura_L2-OMNO2_2020m0301t1319-o83127_v003-2020m0611t114310.he5,OMI-Aura_L2-OMNO2_2020m0301t1458-o83128_v003-2020m0611t114306.he5,OMI-Aura_L2-OMNO2_2020m0301t1637-o83129_v003-2020m0611t114311.he5,OMI-Aura_L2-OMNO2_2020m0301t1816-o83130_v003-2020m0611t114309.he5,OMI-Aura_L2-OMNO2_2020m0301t1955-o83131_v003-2020m0611t114309.he5,OMI-Aura_L2-OMNO2_2020m0301t2134-o83132_v003-2020m0611t114313.he5,OMI-Aura_L2-OMNO2_2020m0301t2312-o83133_v003-2020m0611t114308.he5
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.InstrumentName: OMI
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.ProcessLevel: 3d
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.Period: Daily
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleYear: 2020
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleMonth: 3
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleDay: 1
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.GranuleDayOfYear: 61
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.StartUTC: 2020.0
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.EndUTC: 2020-03-02T00:00:00.000000Z
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.TAI93At0zOfGranule: 857088010.0
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.OrbitCount: 16
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.StartOrbit: 17582
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.EndOrbit: 17597
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.OrbitNumber: [83118 83119 83120 83121 83122 83123 83124 83125 83126 83127 83128 83129
#  83130 83131 83132 83133]
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.Resolution:  0.250 degrees
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.PGE: OMNO2d
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.PGEVersion: \"1.0.5.03\"
#     HDFEOS_ADDITIONAL_FILE_ATTRIBUTES.fullnamepath: /HDFEOS/ADDITIONAL/FILE_ATTRIBUTES
#     HDFEOS_GRIDS_ColumnAmountNO2.GCTPProjectionCode: 0
#     HDFEOS_GRIDS_ColumnAmountNO2.Projection: Geographic
#     HDFEOS_GRIDS_ColumnAmountNO2.GridOrigin: Center
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpacing: (0.25, 0.25)
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpacingUnit: deg
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpan: (-180,180,-90,90)
#     HDFEOS_GRIDS_ColumnAmountNO2.GridSpanUnit: deg
#     HDFEOS_GRIDS_ColumnAmountNO2.NumberOfLongitudesInGrid: 1440
#     HDFEOS_GRIDS_ColumnAmountNO2.NumberOfLatitudesInGrid: 720
#     HDFEOS_GRIDS_ColumnAmountNO2.fullnamepath: /HDFEOS/GRIDS/ColumnAmountNO2
#     HDFEOS_INFORMATION.HDFEOSVersion: HDFEOS_5.1.12
#     HDFEOS_INFORMATION.fullnamepath: /HDFEOS INFORMATION
#     history: 2021-07-21 06:11:08 GMT Hyrax-1.16.3 https://acdisc.gesdisc.eosdis.nasa.gov/opendap/HDF-EOS5/Aura_OMI_Level3/OMNO2d.003/2020/OMI-Aura_L3-OMNO2d_2020m0301_v003-2020m0611t080447.he5.nc4?ColumnAmountNO2TropCloudScreened[521:524][423:434],lat[521:524],lon[423:434]
#     dimensions(sizes): lat(4), lon(12)
#     variables(dimensions): float32 ColumnAmountNO2TropCloudScreened(lat, lon), float32 lon(lon), float32 lat(lat)
#     groups:

# %%
print(data.variables['ColumnAmountNO2TropCloudScreened'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 ColumnAmountNO2TropCloudScreened(lat, lon)
#     _FillValue: -1.2676506e+30
#     missing_value: -1.2676506e+30
#     scale_factor: 1.0
#     add_offset: 0.0
#     units: molec/cm2
#     title: NO2 tropospheric column density, screened for CloudFraction < 30%
#     Description: Field=ColumnAmountNO2Trop,StdField=ColumnAmountNO2TropStd,SolarZenithAngle=[0:85],CloudFraction=[0:300],VcdQualityFlags=~19,XTrackQualityFlags=~[1:254],TerrainReflectivity=[0:1000]
#     origname: ColumnAmountNO2TropCloudScreened
#     fullnamepath: /HDFEOS/GRIDS/ColumnAmountNO2/Data Fields/ColumnAmountNO2TropCloudScreened
#     orig_dimname_list: YDim XDim
# unlimited dimensions:
# current shape = (4, 12)
# filling on
